# %%
#| hide
from richcal.heatmap import *

# %% [markdown]
# # richcal
#
# > Rich terminal calendar heatmap widgets

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install richcal in Development mode

# %% [markdown]
# ```sh
# # make sure richcal package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to richcal
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/doyu/richcal.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c doyu richcal
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install richcal
# ```
#
#
# [repo]: https://github.com/doyu/richcal
# [docs]: https://doyu.github.io/richcal/
# [pypi]: https://pypi.org/project/richcal/
# [conda]: https://anaconda.org/doyu/richcal

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/doyu/richcal
# [docs]: https://doyu.github.io/richcal/
# [pypi]: https://pypi.org/project/richcal/
# [conda]: https://anaconda.org/doyu/richcal

# %% [markdown]
# ## How to use

# %%
#| eval: false
from datetime import date, timedelta
from rich.console import Console
from richcal import CalendarHeatmap

data = {date(2026, 1, 1) + timedelta(days=i): (i * 7) % 23 for i in range(170)}
Console().print(CalendarHeatmap(data, date(2026, 1, 1), date(2026, 12, 31), as_of=date(2026, 6, 23)))
